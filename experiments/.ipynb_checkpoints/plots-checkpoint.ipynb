# %%
# %%capture

# %pip install seaborn pandas numpy

# !jupyter nbextension install jupyter_ascending --user --py && \
# jupyter nbextension enable jupyter_ascending --user --py && \
# jupyter serverextension enable jupyter_ascending --user --py

# %%
import seaborn as sns

sns.set_style("darkgrid")
sns.color_palette("deep")
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]

# %%
import sys
from os import path
sys.path.append(path.join(".."))

# %%
from mi_scale_2.config import CHANGE_TRENDS_DAYS
from mi_scale_2.weight_util import get_saved_weights

df_ = pd.DataFrame(df).sort_values(by="dt", ascending=False).drop(columns=["unit"])
df_["weight"] = df_["weight"].astype(float)
df_["days"] = df_["dt"].rsub(pd.Timestamp('today')).dt.days
# df_["weeks"] = df_["dt"].rsub(pd.Timestamp('today')).dt.week
# now = pd.datetime.now().replace(hour=0, minute=0, second=0, microsecond=0)
# df_["days"] = df_["dt"].rsub(pd.Timestamp.now().floor('week'))
df_ = df_.drop(columns=["timestamp"])
# df_ = df_.groupby('days').mean()
df_["weight_delta"] = df_["weight"].rsub(df_["weight"].iloc[0])
# df_["gain"] = df_["weight"] < df_["weight"].iloc[0] #"Gain" if df_["weight"] < df_["weight"].iloc[0] else "Loss"
df_["trend"] = df_["weight_delta"].apply(lambda delta: "Gain" if delta > 0 else "Loss")
# df_["trend"].loc[df_["weight_delta", "trend"] > 0] = "Gain"
# df_["trend"].loc[df_["weight_delta", "trend"] < 0] = "Loss"
# df_["trend"].loc[df_["weight_delta", "trend"] == 0] = "No change"
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df_) #.drop_duplicates("days", keep="last"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/tslibs/offsets.pyx:4089, in pandas._libs.tslibs.offsets._get_offset()
#
# KeyError: 'WEEK'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/tslibs/offsets.pyx:4190, in pandas._libs.tslibs.offsets.to_offset()
#
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/tslibs/offsets.pyx:4095, in pandas._libs.tslibs.offsets._get_offset()
#
# ValueError: Invalid frequency: WEEK
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 9
#       5 df_["weight"] = df_["weight"].astype(float)
#       6 # df_["days"] = df_["dt"].rsub(pd.Timestamp('today')).dt.days
#       7 # df_["weeks"] = df_["dt"].rsub(pd.Timestamp('today')).dt.week
#       8 # now = pd.datetime.now().replace(hour=0, minute=0, second=0, microsecond=0)
# ----> 9 df_["days"] = df_["dt"].rsub(pd.Timestamp.now().floor('week'))
#      10 df_ = df_.drop(columns=["timestamp"])
#      11 # df_ = df_.groupby('days').mean()
#
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/tslibs/timestamps.pyx:1888, in pandas._libs.tslibs.timestamps.Timestamp.floor()
#
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/tslibs/timestamps.pyx:1678, in pandas._libs.tslibs.timestamps.Timestamp._round()
#
# File ~/.local/lib/python3.9/site-packages/pandas/_libs/tslibs/offsets.pyx:4198, in pandas._libs.tslibs.offsets.to_offset()
#
# ValueError: Invalid frequency: week

# %%
plt.figure(figsize=(10,6), tight_layout=True)

ax = sns.scatterplot(data=df_, x="days", y="weight", hue="trend", palette="Set2", s=60)
ax.set(xlabel="Days since today", ylabel="Weight (kg)")
# ax.legend([True, False], ["Gain", "Loss"], title='Gain/loss', title_fontsize = 12) 
ax.legend(title='Trend', title_fontsize = 12) 
ax
# Out:
# <Axes: xlabel='Days since today', ylabel='Weight (kg)'>

# %%
plt.figure(figsize=(10,6), tight_layout=True)
ax = sns.boxplot(data=df_, x='days', y='weight', palette='Set2', linewidth=2.5)
ax.set(title='Boxplot', xlabel='', ylabel='Height (cm)')
plt.show()
